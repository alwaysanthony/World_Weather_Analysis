# %%
#import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the requests library.
import requests
import sys
sys.path.append('..')

# Import the API key.
from config import weather_api_key
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 766

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bea5d4a9a7b7fef5b2d61a5aeef034c6

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        current_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": current_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | shizukuishi
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | vaini
# Processing Record 5 of Set 1 | saint-philippe
# Processing Record 6 of Set 1 | lazaro cardenas
# Processing Record 7 of Set 1 | meulaboh
# Processing Record 8 of Set 1 | crab hill
# City not found. Skipping...
# Processing Record 9 of Set 1 | cidreira
# Processing Record 10 of Set 1 | barrow
# Processing Record 11 of Set 1 | arcata
# Processing Record 12 of Set 1 | sao joao da barra
# Processing Record 13 of Set 1 | atbasar
# Processing Record 14 of Set 1 | katsuura
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 1 | bluff
# Processing Record 18 of Set 1 | puerto ayora
# Processing Record 19 of Set 1 | stephenville crossing
# Processing Record 20 of Set 1 | kysyl-syr
# Processing Record 21 of Set 1 | kahului
# Processing Record 22 of Set 1 | yellowknife
# Processing Record 23 of Set 1 | jamestown
# Processing Record 24 of Set 1 | punta arenas
# Processing Record 25 of Set 1 | bathsheba
# Processing Record 26 of Set 1 | taihe
# Processing Record 27 of Set 1 | rikitea
# Processing Record 28 of Set 1 | kirakira
# Processing Record 29 of Set 1 | dingzhou
# Processing Record 30 of Set 1 | hobart
# Processing Record 31 of Set 1 | yar-sale
# Processing Record 32 of Set 1 | mount gambier
# Processing Record 33 of Set 1 | tecolutla
# Processing Record 34 of Set 1 | cherskiy
# Processing Record 35 of Set 1 | cabo san lucas
# Processing Record 36 of Set 1 | shenzhen
# Processing Record 37 of Set 1 | shelburne
# Processing Record 38 of Set 1 | kodiak
# Processing Record 39 of Set 1 | sohag
# Processing Record 40 of Set 1 | bitung
# Processing Record 41 of Set 1 | chokurdakh
# Processing Record 42 of Set 1 | ribeira grande
# Processing Record 43 of Set 1 | khatanga
# Processing Record 44 of Set 1 | souillac
# Processing Record 45 of Set 1 | katobu
# Processing Record 46 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 1 | tuktoyaktuk
# Processing Record 48 of Set 1 | hermanus
# Processing Record 49 of Set 1 | hay river
# Processing Record 50 of Set 1 | new norfolk
# Processing Record 1 of Set 2 | lusaka
# Processing Record 2 of Set 2 | tuatapere
# Processing Record 3 of Set 2 | mahebourg
# Processing Record 4 of Set 2 | sinnamary
# Processing Record 5 of Set 2 | kiknur
# Processing Record 6 of Set 2 | sampit
# Processing Record 7 of Set 2 | airai
# Processing Record 8 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 2 | bulungu
# Processing Record 10 of Set 2 | salalah
# Processing Record 11 of Set 2 | maarianhamina
# Processing Record 12 of Set 2 | lebu
# Processing Record 13 of Set 2 | traverse city
# Processing Record 14 of Set 2 | maneromango
# Processing Record 15 of Set 2 | san andres itzapa
# Processing Record 16 of Set 2 | kruisfontein
# Processing Record 17 of Set 2 | severo-kurilsk
# Processing Record 18 of Set 2 | saint-augustin
# Processing Record 19 of Set 2 | saint-joseph
# Processing Record 20 of Set 2 | lokosovo
# Processing Record 21 of Set 2 | bandarbeyla
# Processing Record 22 of Set 2 | dikson
# Processing Record 23 of Set 2 | ormara
# Processing Record 24 of Set 2 | debre tabor
# Processing Record 25 of Set 2 | atuona
# Processing Record 26 of Set 2 | flin flon
# Processing Record 27 of Set 2 | tavda
# Processing Record 28 of Set 2 | campbellton
# Processing Record 29 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 30 of Set 2 | hithadhoo
# Processing Record 31 of Set 2 | clyde river
# Processing Record 32 of Set 2 | hilo
# Processing Record 33 of Set 2 | port elizabeth
# Processing Record 34 of Set 2 | luderitz
# Processing Record 35 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 2 | auki
# Processing Record 37 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 39 of Set 2 | aflu
# City not found. Skipping...
# Processing Record 40 of Set 2 | leningradskiy
# Processing Record 41 of Set 2 | kavaratti
# Processing Record 42 of Set 2 | nikolskoye
# Processing Record 43 of Set 2 | udachnyy
# Processing Record 44 of Set 2 | ahipara
# Processing Record 45 of Set 2 | mlimba
# Processing Record 46 of Set 2 | valday
# Processing Record 47 of Set 2 | geraldton
# Processing Record 48 of Set 2 | necochea
# Processing Record 49 of Set 2 | bredasdorp
# Processing Record 50 of Set 2 | narsaq
# Processing Record 1 of Set 3 | cape town
# Processing Record 2 of Set 3 | nanortalik
# Processing Record 3 of Set 3 | santa maria
# Processing Record 4 of Set 3 | beringovskiy
# Processing Record 5 of Set 3 | albany
# Processing Record 6 of Set 3 | faya
# Processing Record 7 of Set 3 | la ronge
# Processing Record 8 of Set 3 | castro
# Processing Record 9 of Set 3 | pedernales
# Processing Record 10 of Set 3 | hervey bay
# Processing Record 11 of Set 3 | tabou
# Processing Record 12 of Set 3 | xining
# Processing Record 13 of Set 3 | bethel
# Processing Record 14 of Set 3 | aklavik
# Processing Record 15 of Set 3 | bambous virieux
# Processing Record 16 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 3 | barrie
# Processing Record 18 of Set 3 | manzil tamim
# City not found. Skipping...
# Processing Record 19 of Set 3 | college
# Processing Record 20 of Set 3 | dokka
# Processing Record 21 of Set 3 | remanso
# Processing Record 22 of Set 3 | deputatskiy
# Processing Record 23 of Set 3 | tanout
# Processing Record 24 of Set 3 | arraial do cabo
# Processing Record 25 of Set 3 | cravo norte
# Processing Record 26 of Set 3 | port macquarie
# Processing Record 27 of Set 3 | casper
# Processing Record 28 of Set 3 | ilulissat
# Processing Record 29 of Set 3 | kapaa
# Processing Record 30 of Set 3 | linxia
# Processing Record 31 of Set 3 | youkounkoun
# Processing Record 32 of Set 3 | azangaro
# Processing Record 33 of Set 3 | tarudant
# City not found. Skipping...
# Processing Record 34 of Set 3 | cambyreta
# City not found. Skipping...
# Processing Record 35 of Set 3 | byron bay
# Processing Record 36 of Set 3 | viedma
# Processing Record 37 of Set 3 | east london
# Processing Record 38 of Set 3 | qaanaaq
# Processing Record 39 of Set 3 | dingle
# Processing Record 40 of Set 3 | korosladany
# Processing Record 41 of Set 3 | tucurui
# Processing Record 42 of Set 3 | panaba
# Processing Record 43 of Set 3 | mahibadhoo
# Processing Record 44 of Set 3 | safaga
# Processing Record 45 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 46 of Set 3 | nanakuli
# Processing Record 47 of Set 3 | fort nelson
# Processing Record 48 of Set 3 | preobrazheniye
# Processing Record 49 of Set 3 | amahai
# Processing Record 50 of Set 3 | nador
# Processing Record 1 of Set 4 | mackenzie
# Processing Record 2 of Set 4 | upernavik
# Processing Record 3 of Set 4 | daxian
# City not found. Skipping...
# Processing Record 4 of Set 4 | zyryanovsk
# Processing Record 5 of Set 4 | pangai
# Processing Record 6 of Set 4 | camacha
# Processing Record 7 of Set 4 | bamiantong
# Processing Record 8 of Set 4 | avarua
# Processing Record 9 of Set 4 | pancol
# Processing Record 10 of Set 4 | chuy
# Processing Record 11 of Set 4 | yayva
# Processing Record 12 of Set 4 | torbay
# Processing Record 13 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 14 of Set 4 | ishigaki
# Processing Record 15 of Set 4 | provideniya
# Processing Record 16 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 4 | sept-iles
# Processing Record 18 of Set 4 | grants
# Processing Record 19 of Set 4 | ixtapa
# Processing Record 20 of Set 4 | tautira
# Processing Record 21 of Set 4 | daru
# Processing Record 22 of Set 4 | fare
# Processing Record 23 of Set 4 | avera
# Processing Record 24 of Set 4 | ganzhou
# Processing Record 25 of Set 4 | pevek
# Processing Record 26 of Set 4 | dicabisagan
# Processing Record 27 of Set 4 | grand gaube
# Processing Record 28 of Set 4 | bandar
# Processing Record 29 of Set 4 | emerald
# Processing Record 30 of Set 4 | creel
# Processing Record 31 of Set 4 | carauari
# Processing Record 32 of Set 4 | flagstaff
# Processing Record 33 of Set 4 | kashi
# Processing Record 34 of Set 4 | iqaluit
# Processing Record 35 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 36 of Set 4 | talnakh
# Processing Record 37 of Set 4 | melbu
# Processing Record 38 of Set 4 | ancud
# Processing Record 39 of Set 4 | carmen
# Processing Record 40 of Set 4 | talakan
# Processing Record 41 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 42 of Set 4 | lotoshino
# Processing Record 43 of Set 4 | lodwar
# Processing Record 44 of Set 4 | kipini
# Processing Record 45 of Set 4 | katangli
# Processing Record 46 of Set 4 | bengkulu
# Processing Record 47 of Set 4 | biltine
# Processing Record 48 of Set 4 | hamilton
# Processing Record 49 of Set 4 | hasanabad
# Processing Record 50 of Set 4 | plouzane
# Processing Record 1 of Set 5 | port blair
# Processing Record 2 of Set 5 | port alfred
# Processing Record 3 of Set 5 | matadi
# Processing Record 4 of Set 5 | lompoc
# Processing Record 5 of Set 5 | hualmay
# Processing Record 6 of Set 5 | aykhal
# Processing Record 7 of Set 5 | agadez
# Processing Record 8 of Set 5 | khudumelapye
# Processing Record 9 of Set 5 | kpandu
# Processing Record 10 of Set 5 | arukutti
# Processing Record 11 of Set 5 | prochnookopskaya
# Processing Record 12 of Set 5 | sobolevo
# Processing Record 13 of Set 5 | bambanglipuro
# Processing Record 14 of Set 5 | batemans bay
# Processing Record 15 of Set 5 | komsomolskiy
# Processing Record 16 of Set 5 | zhigansk
# Processing Record 17 of Set 5 | walvis bay
# Processing Record 18 of Set 5 | samarai
# Processing Record 19 of Set 5 | georgetown
# Processing Record 20 of Set 5 | codrington
# Processing Record 21 of Set 5 | gimli
# Processing Record 22 of Set 5 | potsdam
# Processing Record 23 of Set 5 | yulara
# Processing Record 24 of Set 5 | rio gallegos
# Processing Record 25 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 26 of Set 5 | longyearbyen
# Processing Record 27 of Set 5 | ponta do sol
# Processing Record 28 of Set 5 | namatanai
# Processing Record 29 of Set 5 | nouadhibou
# Processing Record 30 of Set 5 | olafsvik
# Processing Record 31 of Set 5 | porbandar
# Processing Record 32 of Set 5 | saskylakh
# Processing Record 33 of Set 5 | gudari
# Processing Record 34 of Set 5 | paucartambo
# City not found. Skipping...
# Processing Record 35 of Set 5 | wilmington
# Processing Record 36 of Set 5 | lagoa
# Processing Record 37 of Set 5 | bethanien
# Processing Record 38 of Set 5 | taoudenni
# Processing Record 39 of Set 5 | edd
# Processing Record 40 of Set 5 | alofi
# Processing Record 41 of Set 5 | marana
# Processing Record 42 of Set 5 | kholm
# Processing Record 43 of Set 5 | padang
# Processing Record 44 of Set 5 | karatuzskoye
# Processing Record 45 of Set 5 | paamiut
# Processing Record 46 of Set 5 | bayburt
# Processing Record 47 of Set 5 | muros
# Processing Record 48 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 49 of Set 5 | boshnyakovo
# Processing Record 50 of Set 5 | havelock
# Processing Record 1 of Set 6 | srednekolymsk
# Processing Record 2 of Set 6 | thompson
# Processing Record 3 of Set 6 | tashtagol
# Processing Record 4 of Set 6 | baghdad
# Processing Record 5 of Set 6 | dehloran
# Processing Record 6 of Set 6 | belousovka
# Processing Record 7 of Set 6 | idrinskoye
# Processing Record 8 of Set 6 | inongo
# Processing Record 9 of Set 6 | qaqortoq
# Processing Record 10 of Set 6 | taltal
# Processing Record 11 of Set 6 | yuli
# Processing Record 12 of Set 6 | port hardy
# Processing Record 13 of Set 6 | alta floresta
# Processing Record 14 of Set 6 | san patricio
# Processing Record 15 of Set 6 | caravelas
# Processing Record 16 of Set 6 | fortuna
# Processing Record 17 of Set 6 | kavieng
# Processing Record 18 of Set 6 | tarakan
# Processing Record 19 of Set 6 | khash
# Processing Record 20 of Set 6 | tiznit
# Processing Record 21 of Set 6 | ipswich
# Processing Record 22 of Set 6 | vila
# Processing Record 23 of Set 6 | queenstown
# Processing Record 24 of Set 6 | bonavista
# Processing Record 25 of Set 6 | moerai
# Processing Record 26 of Set 6 | candawaga
# City not found. Skipping...
# Processing Record 27 of Set 6 | husavik
# Processing Record 28 of Set 6 | nkhotakota
# Processing Record 29 of Set 6 | acari
# Processing Record 30 of Set 6 | sur
# Processing Record 31 of Set 6 | bani
# Processing Record 32 of Set 6 | laguna
# Processing Record 33 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 6 | skjervoy
# Processing Record 35 of Set 6 | vila velha
# Processing Record 36 of Set 6 | nabire
# Processing Record 37 of Set 6 | civitanova marche
# Processing Record 38 of Set 6 | ponta delgada
# Processing Record 39 of Set 6 | nhulunbuy
# Processing Record 40 of Set 6 | oktyabrskiy
# Processing Record 41 of Set 6 | raton
# Processing Record 42 of Set 6 | awjilah
# Processing Record 43 of Set 6 | lar
# Processing Record 44 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 45 of Set 6 | sitka
# Processing Record 46 of Set 6 | san quintin
# Processing Record 47 of Set 6 | letterkenny
# Processing Record 48 of Set 6 | roebourne
# Processing Record 49 of Set 6 | bay city
# Processing Record 50 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 1 of Set 7 | leh
# Processing Record 2 of Set 7 | gizo
# Processing Record 3 of Set 7 | robstown
# Processing Record 4 of Set 7 | nebolchi
# Processing Record 5 of Set 7 | sao filipe
# Processing Record 6 of Set 7 | praia
# Processing Record 7 of Set 7 | gornopravdinsk
# Processing Record 8 of Set 7 | luau
# Processing Record 9 of Set 7 | bam
# Processing Record 10 of Set 7 | kaitangata
# Processing Record 11 of Set 7 | lorengau
# Processing Record 12 of Set 7 | zhanatas
# City not found. Skipping...
# Processing Record 13 of Set 7 | jacareacanga
# Processing Record 14 of Set 7 | acapulco
# Processing Record 15 of Set 7 | grand forks
# Processing Record 16 of Set 7 | lubao
# Processing Record 17 of Set 7 | porto walter
# Processing Record 18 of Set 7 | touros
# Processing Record 19 of Set 7 | fairbanks
# Processing Record 20 of Set 7 | sibu
# Processing Record 21 of Set 7 | butaritari
# Processing Record 22 of Set 7 | hermiston
# Processing Record 23 of Set 7 | morondava
# Processing Record 24 of Set 7 | lavrentiya
# Processing Record 25 of Set 7 | tasiilaq
# Processing Record 26 of Set 7 | bonfim
# Processing Record 27 of Set 7 | azimur
# City not found. Skipping...
# Processing Record 28 of Set 7 | agadir
# Processing Record 29 of Set 7 | upata
# Processing Record 30 of Set 7 | carnarvon
# Processing Record 31 of Set 7 | kununurra
# Processing Record 32 of Set 7 | parana
# Processing Record 33 of Set 7 | saldanha
# Processing Record 34 of Set 7 | matagami
# Processing Record 35 of Set 7 | roma
# Processing Record 36 of Set 7 | gat
# Processing Record 37 of Set 7 | grindavik
# Processing Record 38 of Set 7 | kargil
# Processing Record 39 of Set 7 | shagonar
# Processing Record 40 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 41 of Set 7 | maloy
# Processing Record 42 of Set 7 | ewa beach
# Processing Record 43 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 44 of Set 7 | vao
# Processing Record 45 of Set 7 | rayong
# Processing Record 46 of Set 7 | flinders
# Processing Record 47 of Set 7 | sataua
# City not found. Skipping...
# Processing Record 48 of Set 7 | maykain
# City not found. Skipping...
# Processing Record 49 of Set 7 | two rivers
# Processing Record 50 of Set 7 | kihei
# Processing Record 1 of Set 8 | alice springs
# Processing Record 2 of Set 8 | berlevag
# Processing Record 3 of Set 8 | inirida
# Processing Record 4 of Set 8 | myitkyina
# Processing Record 5 of Set 8 | saryg-sep
# Processing Record 6 of Set 8 | esso
# Processing Record 7 of Set 8 | kampong thum
# Processing Record 8 of Set 8 | djougou
# Processing Record 9 of Set 8 | chifeng
# Processing Record 10 of Set 8 | hofn
# Processing Record 11 of Set 8 | manga
# Processing Record 12 of Set 8 | mar del plata
# Processing Record 13 of Set 8 | scarborough
# Processing Record 14 of Set 8 | coihaique
# Processing Record 15 of Set 8 | umm lajj
# Processing Record 16 of Set 8 | chara
# Processing Record 17 of Set 8 | valparaiso
# Processing Record 18 of Set 8 | prieska
# Processing Record 19 of Set 8 | la plata
# Processing Record 20 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 21 of Set 8 | dali
# Processing Record 22 of Set 8 | ranau
# Processing Record 23 of Set 8 | campeche
# Processing Record 24 of Set 8 | kolchugino
# Processing Record 25 of Set 8 | zaozerne
# Processing Record 26 of Set 8 | porto santo
# Processing Record 27 of Set 8 | dinsor
# City not found. Skipping...
# Processing Record 28 of Set 8 | krasnyy yar
# Processing Record 29 of Set 8 | alugan
# Processing Record 30 of Set 8 | portland
# Processing Record 31 of Set 8 | buerarema
# Processing Record 32 of Set 8 | san cristobal
# Processing Record 33 of Set 8 | lakatoro
# Processing Record 34 of Set 8 | mehamn
# Processing Record 35 of Set 8 | hambantota
# Processing Record 36 of Set 8 | roura
# Processing Record 37 of Set 8 | nome
# Processing Record 38 of Set 8 | atar
# Processing Record 39 of Set 8 | anloga
# Processing Record 40 of Set 8 | ramos arizpe
# Processing Record 41 of Set 8 | shubarshi
# Processing Record 42 of Set 8 | godfrey
# Processing Record 43 of Set 8 | buin
# Processing Record 44 of Set 8 | vallenar
# Processing Record 45 of Set 8 | cabcaben
# Processing Record 46 of Set 8 | adrar
# Processing Record 47 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 8 | itoman
# Processing Record 49 of Set 8 | nantucket
# Processing Record 50 of Set 8 | soissons
# Processing Record 1 of Set 9 | itarema
# Processing Record 2 of Set 9 | malartic
# Processing Record 3 of Set 9 | severodvinsk
# Processing Record 4 of Set 9 | huarmey
# Processing Record 5 of Set 9 | timiryazevskoye
# Processing Record 6 of Set 9 | kushiro
# Processing Record 7 of Set 9 | khani
# Processing Record 8 of Set 9 | mayo
# Processing Record 9 of Set 9 | prince rupert
# Processing Record 10 of Set 9 | cansancao
# Processing Record 11 of Set 9 | solano
# Processing Record 12 of Set 9 | virginia beach
# Processing Record 13 of Set 9 | chiang rai
# Processing Record 14 of Set 9 | pemberton
# Processing Record 15 of Set 9 | kushima
# Processing Record 16 of Set 9 | mitzic
# Processing Record 17 of Set 9 | svolvaer
# Processing Record 18 of Set 9 | kitui
# Processing Record 19 of Set 9 | havre-saint-pierre
# Processing Record 20 of Set 9 | krotoszyn
# Processing Record 21 of Set 9 | shache
# Processing Record 22 of Set 9 | port lincoln
# Processing Record 23 of Set 9 | yaan
# Processing Record 24 of Set 9 | krasnyy chikoy
# Processing Record 25 of Set 9 | minna
# Processing Record 26 of Set 9 | kloulklubed
# Processing Record 27 of Set 9 | arlit
# Processing Record 28 of Set 9 | te anau
# Processing Record 29 of Set 9 | saint george
# Processing Record 30 of Set 9 | wajir
# Processing Record 31 of Set 9 | pereira barreto
# Processing Record 32 of Set 9 | vabalninkas
# Processing Record 33 of Set 9 | bocaranga
# City not found. Skipping...
# Processing Record 34 of Set 9 | emba
# Processing Record 35 of Set 9 | zabid
# Processing Record 36 of Set 9 | pisco
# Processing Record 37 of Set 9 | cockburn town
# Processing Record 38 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 9 | omsukchan
# Processing Record 40 of Set 9 | westport
# Processing Record 41 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 42 of Set 9 | homer
# Processing Record 43 of Set 9 | hobyo
# Processing Record 44 of Set 9 | turukhansk
# Processing Record 45 of Set 9 | biu
# Processing Record 46 of Set 9 | ken caryl
# Processing Record 47 of Set 9 | saint-pierre
# Processing Record 48 of Set 9 | laiagam
# City not found. Skipping...
# Processing Record 49 of Set 9 | sola
# Processing Record 50 of Set 9 | tecoanapa
# Processing Record 1 of Set 10 | anamur
# Processing Record 2 of Set 10 | kupang
# Processing Record 3 of Set 10 | doha
# Processing Record 4 of Set 10 | zwedru
# Processing Record 5 of Set 10 | monaghan
# Processing Record 6 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 7 of Set 10 | chicama
# Processing Record 8 of Set 10 | youhao
# Processing Record 9 of Set 10 | kamiiso
# Processing Record 10 of Set 10 | barbar
# City not found. Skipping...
# Processing Record 11 of Set 10 | norman wells
# Processing Record 12 of Set 10 | diego de almagro
# Processing Record 13 of Set 10 | road town
# Processing Record 14 of Set 10 | rundu
# Processing Record 15 of Set 10 | tiarei
# Processing Record 16 of Set 10 | inhambane
# Processing Record 17 of Set 10 | chandbali
# Processing Record 18 of Set 10 | trois-rivieres
# Processing Record 19 of Set 10 | tateyama
# Processing Record 20 of Set 10 | phuket
# Processing Record 21 of Set 10 | roros
# Processing Record 22 of Set 10 | los llanos de aridane
# Processing Record 23 of Set 10 | la mira
# Processing Record 24 of Set 10 | sikonge
# Processing Record 25 of Set 10 | baykit
# Processing Record 26 of Set 10 | chor
# Processing Record 27 of Set 10 | plettenberg bay
# Processing Record 28 of Set 10 | praia da vitoria
# Processing Record 29 of Set 10 | miri
# Processing Record 30 of Set 10 | korla
# Processing Record 31 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 32 of Set 10 | tadine
# Processing Record 33 of Set 10 | nizwa
# Processing Record 34 of Set 10 | pacific grove
# Processing Record 35 of Set 10 | tilichiki
# Processing Record 36 of Set 10 | kaeo
# Processing Record 37 of Set 10 | lifford
# Processing Record 38 of Set 10 | las varas
# Processing Record 39 of Set 10 | miracema do tocantins
# Processing Record 40 of Set 10 | haines junction
# Processing Record 41 of Set 10 | mount isa
# Processing Record 42 of Set 10 | dongying
# Processing Record 43 of Set 10 | abu samrah
# Processing Record 44 of Set 10 | guane
# Processing Record 45 of Set 10 | pak phanang
# Processing Record 46 of Set 10 | cabatuan
# Processing Record 47 of Set 10 | sabzevar
# Processing Record 48 of Set 10 | rochester
# Processing Record 49 of Set 10 | ploemeur
# Processing Record 50 of Set 10 | rawson
# Processing Record 1 of Set 11 | tinjah
# City not found. Skipping...
# Processing Record 2 of Set 11 | nyurba
# Processing Record 3 of Set 11 | stykkisholmur
# Processing Record 4 of Set 11 | kamenka
# Processing Record 5 of Set 11 | tiksi
# Processing Record 6 of Set 11 | dalby
# Processing Record 7 of Set 11 | garcia
# Processing Record 8 of Set 11 | sosua
# Processing Record 9 of Set 11 | chiriqui grande
# Processing Record 10 of Set 11 | kichmengskiy gorodok
# Processing Record 11 of Set 11 | honningsvag
# Processing Record 12 of Set 11 | shingu
# Processing Record 13 of Set 11 | rawatsar
# Processing Record 14 of Set 11 | poum
# Processing Record 15 of Set 11 | zhigalovo
# Processing Record 16 of Set 11 | beloha
# Processing Record 17 of Set 11 | boa vista
# Processing Record 18 of Set 11 | le port
# Processing Record 19 of Set 11 | limbang
# Processing Record 20 of Set 11 | gamba
# Processing Record 21 of Set 11 | gairo
# Processing Record 22 of Set 11 | namibe
# Processing Record 23 of Set 11 | bosaso
# Processing Record 24 of Set 11 | orlik
# Processing Record 25 of Set 11 | camopi
# Processing Record 26 of Set 11 | khandyga
# Processing Record 27 of Set 11 | victoria
# Processing Record 28 of Set 11 | muncar
# Processing Record 29 of Set 11 | kamaishi
# Processing Record 30 of Set 11 | svetlaya
# Processing Record 31 of Set 11 | kayes
# Processing Record 32 of Set 11 | aksay
# Processing Record 33 of Set 11 | valdivia
# Processing Record 34 of Set 11 | formoso do araguaia
# City not found. Skipping...
# Processing Record 35 of Set 11 | little current
# Processing Record 36 of Set 11 | zhangye
# Processing Record 37 of Set 11 | chandler
# Processing Record 38 of Set 11 | solovetskiy
# City not found. Skipping...
# Processing Record 39 of Set 11 | cuiaba
# Processing Record 40 of Set 11 | vera cruz
# Processing Record 41 of Set 11 | labuhan
# Processing Record 42 of Set 11 | baishishan
# Processing Record 43 of Set 11 | fredericksburg
# Processing Record 44 of Set 11 | ternate
# Processing Record 45 of Set 11 | constitucion
# Processing Record 46 of Set 11 | klaksvik
# Processing Record 47 of Set 11 | serenje
# Processing Record 48 of Set 11 | shitkino
# Processing Record 49 of Set 11 | kuloy
# Processing Record 50 of Set 11 | barreirinhas
# Processing Record 1 of Set 12 | arman
# Processing Record 2 of Set 12 | ambilobe
# Processing Record 3 of Set 12 | ciudad del maiz
# Processing Record 4 of Set 12 | vostok
# Processing Record 5 of Set 12 | tsabong
# Processing Record 6 of Set 12 | tutoia
# Processing Record 7 of Set 12 | aripuana
# Processing Record 8 of Set 12 | atocha
# Processing Record 9 of Set 12 | kiunga
# Processing Record 10 of Set 12 | cherepanovo
# Processing Record 11 of Set 12 | nelson bay
# Processing Record 12 of Set 12 | dwarka
# Processing Record 13 of Set 12 | solnechnyy
# Processing Record 14 of Set 12 | keti bandar
# Processing Record 15 of Set 12 | kaka
# Processing Record 16 of Set 12 | manono
# Processing Record 17 of Set 12 | rochegda
# Processing Record 18 of Set 12 | lerwick
# Processing Record 19 of Set 12 | jalpaiguri
# Processing Record 20 of Set 12 | cuauhtemoc
# Processing Record 21 of Set 12 | oyama
# Processing Record 22 of Set 12 | kieta
# Processing Record 23 of Set 12 | dabhol
# Processing Record 24 of Set 12 | guerrero negro
# Processing Record 25 of Set 12 | hukuntsi
# Processing Record 26 of Set 12 | palora
# Processing Record 27 of Set 12 | kutum
# Processing Record 28 of Set 12 | iracoubo
# Processing Record 29 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 30 of Set 12 | ahuimanu
# Processing Record 31 of Set 12 | kalmunai
# Processing Record 32 of Set 12 | kenora
# Processing Record 33 of Set 12 | xuddur
# Processing Record 34 of Set 12 | saint-leu
# Processing Record 35 of Set 12 | zyryanka
# Processing Record 36 of Set 12 | ulaanbaatar
# Processing Record 37 of Set 12 | kuito
# Processing Record 38 of Set 12 | rudnogorsk
# Processing Record 39 of Set 12 | egvekinot
# Processing Record 40 of Set 12 | carballo
# Processing Record 41 of Set 12 | chernyy yar
# Processing Record 42 of Set 12 | chingirlau
# Processing Record 43 of Set 12 | ndele
# Processing Record 44 of Set 12 | isangel
# Processing Record 45 of Set 12 | francisco sa
# Processing Record 46 of Set 12 | tommot
# Processing Record 47 of Set 12 | labytnangi
# Processing Record 48 of Set 12 | henties bay
# Processing Record 49 of Set 12 | pachmarhi
# Processing Record 50 of Set 12 | saint-louis
# Processing Record 1 of Set 13 | marienburg
# Processing Record 2 of Set 13 | soubre
# Processing Record 3 of Set 13 | sidi ali
# Processing Record 4 of Set 13 | coahuayana
# Processing Record 5 of Set 13 | van
# Processing Record 6 of Set 13 | ippy
# Processing Record 7 of Set 13 | blackfoot
# Processing Record 8 of Set 13 | yanan
# City not found. Skipping...
# Processing Record 9 of Set 13 | vanimo
# Processing Record 10 of Set 13 | port-gentil
# Processing Record 11 of Set 13 | fereydunshahr
# Processing Record 12 of Set 13 | sao gabriel da cachoeira
# Processing Record 13 of Set 13 | bonthe
# Processing Record 14 of Set 13 | chumikan
# Processing Record 15 of Set 13 | vrangel
# Processing Record 16 of Set 13 | tokur
# Processing Record 17 of Set 13 | skalistyy
# City not found. Skipping...
# Processing Record 18 of Set 13 | china
# Processing Record 19 of Set 13 | chililabombwe
# Processing Record 20 of Set 13 | acajutla
# Processing Record 21 of Set 13 | priargunsk
# Processing Record 22 of Set 13 | pryluky
# Processing Record 23 of Set 13 | belmonte
# Processing Record 24 of Set 13 | zeya
# Processing Record 25 of Set 13 | matara
# Processing Record 26 of Set 13 | dawlatabad
# Processing Record 27 of Set 13 | kochevo
# Processing Record 28 of Set 13 | heilbron
# Processing Record 29 of Set 13 | kisangani
# Processing Record 30 of Set 13 | nizhniy kuranakh
# Processing Record 31 of Set 13 | high level
# Processing Record 32 of Set 13 | seoul
# Processing Record 33 of Set 13 | skoghall
# Processing Record 34 of Set 13 | ariquemes
# Processing Record 35 of Set 13 | rawah
# Processing Record 36 of Set 13 | coquimbo
# Processing Record 37 of Set 13 | salinopolis
# Processing Record 38 of Set 13 | saltillo
# Processing Record 39 of Set 13 | la palma
# Processing Record 40 of Set 13 | tabuk
# Processing Record 41 of Set 13 | timizart
# Processing Record 42 of Set 13 | goure
# Processing Record 43 of Set 13 | jerome
# Processing Record 44 of Set 13 | san luis
# Processing Record 45 of Set 13 | kinanah
# City not found. Skipping...
# Processing Record 46 of Set 13 | palmares
# Processing Record 47 of Set 13 | miranorte
# City not found. Skipping...
# Processing Record 48 of Set 13 | tura
# Processing Record 49 of Set 13 | alyangula
# Processing Record 50 of Set 13 | faanui
# Processing Record 1 of Set 14 | morehead
# Processing Record 2 of Set 14 | mopti
# Processing Record 3 of Set 14 | ampanihy
# Processing Record 4 of Set 14 | asyut
# Processing Record 5 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 6 of Set 14 | forli
# Processing Record 7 of Set 14 | esperance
# Processing Record 8 of Set 14 | zaranj
# Processing Record 9 of Set 14 | santa fe
# Processing Record 10 of Set 14 | zlitan
# Processing Record 11 of Set 14 | half moon bay
# Processing Record 12 of Set 14 | sinkat
# City not found. Skipping...
# Processing Record 13 of Set 14 | krasnoselkup
# Processing Record 14 of Set 14 | carahue
# Processing Record 15 of Set 14 | zaysan
# Processing Record 16 of Set 14 | harper
# Processing Record 17 of Set 14 | kyren
# Processing Record 18 of Set 14 | pokhara
# Processing Record 19 of Set 14 | mitsamiouli
# Processing Record 20 of Set 14 | santa isabel do rio negro
# Processing Record 21 of Set 14 | hailey
# Processing Record 22 of Set 14 | hampton
# Processing Record 23 of Set 14 | antalaha
# Processing Record 24 of Set 14 | kuryk
# Processing Record 25 of Set 14 | ketchikan
# Processing Record 26 of Set 14 | akyab
# Processing Record 27 of Set 14 | zhob
# Processing Record 28 of Set 14 | vikramasingapuram
# Processing Record 29 of Set 14 | amapa
# Processing Record 30 of Set 14 | macheng
# Processing Record 31 of Set 14 | lashio
# Processing Record 32 of Set 14 | oxford
# Processing Record 33 of Set 14 | tual
# Processing Record 34 of Set 14 | stornoway
# Processing Record 35 of Set 14 | norrtalje
# Processing Record 36 of Set 14 | baker city
# Processing Record 37 of Set 14 | marks
# Processing Record 38 of Set 14 | san francisco
# Processing Record 39 of Set 14 | lamar
# Processing Record 40 of Set 14 | copiapo
# Processing Record 41 of Set 14 | port augusta
# Processing Record 42 of Set 14 | broken hill
# Processing Record 43 of Set 14 | karamea
# City not found. Skipping...
# Processing Record 44 of Set 14 | tongliao
# Processing Record 45 of Set 14 | general cepeda
# Processing Record 46 of Set 14 | kidal
# Processing Record 47 of Set 14 | vredendal
# Processing Record 48 of Set 14 | praya
# Processing Record 49 of Set 14 | thanh hoa
# Processing Record 50 of Set 14 | furano
# Processing Record 1 of Set 15 | mecca
# Processing Record 2 of Set 15 | port keats
# Processing Record 3 of Set 15 | sinjar
# Processing Record 4 of Set 15 | iskateley
# Processing Record 5 of Set 15 | kikwit
# Processing Record 6 of Set 15 | matay
# Processing Record 7 of Set 15 | armacao dos buzios
# City not found. Skipping...
# Processing Record 8 of Set 15 | mehkar
# Processing Record 9 of Set 15 | najran
# Processing Record 10 of Set 15 | buala
# Processing Record 11 of Set 15 | harnosand
# Processing Record 12 of Set 15 | surgut
# Processing Record 13 of Set 15 | nimes
# Processing Record 14 of Set 15 | sao jose da coroa grande
# Processing Record 15 of Set 15 | ca mau
# Processing Record 16 of Set 15 | riyadh
# Processing Record 17 of Set 15 | neiafu
# Processing Record 18 of Set 15 | svetlogorsk
# Processing Record 19 of Set 15 | am timan
# Processing Record 20 of Set 15 | tanda
# Processing Record 21 of Set 15 | calvinia
# Processing Record 22 of Set 15 | krasnaya polyana
# Processing Record 23 of Set 15 | saint-georges
# Processing Record 24 of Set 15 | phangnga
# Processing Record 25 of Set 15 | hagersville
# Processing Record 26 of Set 15 | bilma
# Processing Record 27 of Set 15 | porto novo
# Processing Record 28 of Set 15 | dolores
# Processing Record 29 of Set 15 | cam ranh
# Processing Record 30 of Set 15 | almaznyy
# Processing Record 31 of Set 15 | zapresic
# Processing Record 32 of Set 15 | mariani
# Processing Record 33 of Set 15 | lima
# Processing Record 34 of Set 15 | satinka
# Processing Record 35 of Set 15 | kattivakkam
# Processing Record 36 of Set 15 | lam luk ka
# Processing Record 37 of Set 15 | balykshi
# Processing Record 38 of Set 15 | yanam
# Processing Record 39 of Set 15 | iwanai
# Processing Record 40 of Set 15 | boguchany
# Processing Record 41 of Set 15 | sabha
# Processing Record 42 of Set 15 | zouxian
# City not found. Skipping...
# Processing Record 43 of Set 15 | ambovombe
# Processing Record 44 of Set 15 | santa cruz
# Processing Record 45 of Set 15 | baracoa
# Processing Record 46 of Set 15 | sakaiminato
# Processing Record 47 of Set 15 | skibbereen
# Processing Record 48 of Set 15 | tahta
# Processing Record 49 of Set 15 | asau
# Processing Record 50 of Set 15 | bajil
# Processing Record 1 of Set 16 | verkh-chebula
# Processing Record 2 of Set 16 | chipata
# Processing Record 3 of Set 16 | lata
# Processing Record 4 of Set 16 | kitimat
# Processing Record 5 of Set 16 | foumban
# Processing Record 6 of Set 16 | staryy nadym
# Processing Record 7 of Set 16 | balkanabat
# Processing Record 8 of Set 16 | tripoli
# Processing Record 9 of Set 16 | katsiveli
# City not found. Skipping...
# Processing Record 10 of Set 16 | bereda
# Processing Record 11 of Set 16 | bubaque
# Processing Record 12 of Set 16 | porto uniao
# Processing Record 13 of Set 16 | grand centre
# City not found. Skipping...
# Processing Record 14 of Set 16 | lethem
# Processing Record 15 of Set 16 | sukumo
# Processing Record 16 of Set 16 | burica
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Shizukuishi      JP  39.6833  140.9833     59.77        66          53
# 1          Ushuaia      AR -54.8000  -68.3000     42.46        49          75
# 2          Mataura      NZ -46.1927  168.8643     46.47        81          68
# 3            Vaini      TO -21.2000 -175.2000     80.76        78          20
# 4   Saint-Philippe      RE -21.3585   55.7679     71.19        73          51
# 5  Lazaro Cardenas      MX  17.9583 -102.2000     81.34        67          14
# 6         Meulaboh      ID   4.1363   96.1285     76.21        81          98
# 7         Cidreira      BR -30.1811  -50.2056     58.68        70          90
# 8           Barrow      US  71.2906 -156.7887     33.82        80         100
# 9           Arcata      US  40.8665 -124.0828     65.75        84         100
#
#    Wind Speed Current Description
# 0        6.71       broken clouds
# 1       14.97       broken clouds
# 2        2.51       broken clouds
# 3        5.75          few clouds
# 4       13.00       broken clouds
# 5       11.18          few clouds
# 6        2.77     overcast clouds
# 7        9.15     overcast clouds
# 8       20.71     overcast clouds
# 9        0.00     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
